# %%
# import string
# import nltk 
# import pandas as pd
import re,random, pandas as pd, nltk, string, numpy as np
from collections import defaultdict, Counter
from nltk.corpus import brown, stopwords
from nltk import word_tokenize

# Download required NLTK data
nltk.download('brown')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Step 1 : Retrieve data & inputs
print("Enter the number of sentences (M):")
m = int(input())

while True:
    print("Enter your N-gram size (N) choose 2 or 3:")
    n = int(input())
    if n in [2, 3]:
        break
    print("Invalid input. Please try again.")

print(f"Success! You chose {n}.")

print("Enter your maximum sentence length (maxLen):")
maxlen = int(input())

# brown.words() already returns word-level tokens.
tokens = brown.words()[:200000]
# Out:
# Enter the number of sentences (M):
# Enter your N-gram size (N) choose 2 or 3:
# Success! You chose 3.
# Enter your maximum sentence length (maxLen):

# %%
# Step 2 : Data Preprocessing
def preprocess_tokens(text):
    clean_tokens = []
    for word in text:
        # Convert to lowercase
        clean_word = word.lower()
        # Remove punctuation
        clean_word = re.sub(f"[{re.escape(string.punctuation)}]", "", clean_word)
        # Check if empty or if it is a stop word
        if len(clean_word) > 0 :
            clean_tokens.append(clean_word)
    vocabulary = set(clean_tokens)
    
    return clean_tokens,vocabulary

clean_tokens,vocab = preprocess_tokens(tokens)

print(f"Tokens after cleaning: {len(clean_tokens)}")
print(f"Unique vocabulary words: {len(vocab)}")
# Out:
# Tokens after cleaning: 175998
# Unique vocabulary words: 19722

# %%
# Step 3 : Build the N-gram Models 
def build_ngram_models(tokens,n):
    ngram_counts={}
    prefix_counts={}
    for i in range(len(tokens) - n + 1): 
        pair = tuple(tokens[i:i+n])
        prefix = pair[:-1]
        
        if pair not in ngram_counts:
            ngram_counts[pair] = 1
        else:
            ngram_counts[pair] += 1
        
        if prefix not in prefix_counts:
            prefix_counts[prefix] = 1
        else:
            prefix_counts[prefix] += 1
    
    return prefix_counts,ngram_counts

prefix_counts,ngram_counts = build_ngram_models(clean_tokens,n)
print(f"Total unique {n}-grams: {len(ngram_counts)}")
# Out:
# Total unique 3-grams: 161806

# %%
# Step 4 : Develop the Sentence Generator
voc_sentences = []
while len(voc_sentences) < m:
    prefix = random.choice(list(prefix_counts.keys()))
    sent = list(prefix) 
    print(prefix)
    print("___________")
    #
    while len(sent) < maxlen:
        best_word = None
        highest_prob = -1
        
        for word in vocab:
            candidate_ngram = prefix + (word,)
            # Get the count of this n-gram (default to 0 if it never appeared)
            ngram_count = ngram_counts.get(candidate_ngram,0)
            prob = ngram_count/prefix_counts[prefix]
            
            if prob > highest_prob:
                highest_prob = prob
                best_word = word
        
        # append the chosen word to sentence
        if best_word is not None:
            sent.append(best_word)
        else: 
            break
        # Update the prefix to be the last (n-1) words of the current sentence
        prefix = tuple(sent[-(n-1):])
        
    sentence_text = " ".join(sent)
    voc_sentences.append(sentence_text)
print("\n--- Generated Sentences ---\n")
print('\n'.join(voc_sentences))
# Out:
# ('loper', 'who')
# ___________
# ('error', 'to')
# ___________
# ('the', 'unchartered')
# ___________
# ('toot', 'toot')
# ___________
# ('day', 'world')
# ___________
# ('baseball', 'more')
# ___________
# ('sutherland', 'appeared')
# ___________
# ('1', 'goodis')
# ___________
# ('mixed', 'by')
# ___________
# ('tower', 'will')
# ___________
#
# --- Generated Sentences ---
#
# loper who regularly
# error to print
# the unchartered plane
# toot toot tootsie
# day world trip
# baseball more harm
# sutherland appeared almost
# 1 goodis said
# mixed by their
# tower will be
